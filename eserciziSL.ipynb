# %% [markdown]
# ## Primo Esercizio
# Utilizzate la linear regression per analizzare il dataframe di esempio in cui abbiamo le Calorie bruciate in base al peso della persona che fa esercizio fisico con la montain bike, allenate l'algoritmo, testatelo e poi realizzate un grafico

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('calories.csv', index_col=0)
print(df.head())

# %%
y.min()

# %%
y.max()

# %%
X = df[['kg']]
y = df['calories']

X_train, X_test, y_train ,y_test= train_test_split(X,y)

# %%
X_train

# %%
X_test

# %%
y_test

# %%
y_train

# %% [markdown]
# ##### alleniamolo

# %%
model= LinearRegression()
model.fit(X_train,y_train)

# %%
model.coef_

# %%
y_pred = model.predict(X_test)

y_pred

# %% [markdown]
# #### valutatori

# %%
mse = mean_squared_error(y_test,y_pred)
mse

# %%
r2 = r2_score(y_test, y_pred)
r2

# %%
plt.scatter(X_test,y_test, color="red")
plt.plot(X_test, y_pred, color="yellow")

plt.xticks(())
plt.yticks(())

plt.show()

# %%
from sklearn.metrics import PredictionErrorDisplay

display= PredictionErrorDisplay(y_true=y_test,y_pred=y_pred)
display.plot()
plt.show()

# %% [markdown]
# ## Secondo Esercizio
# Utilizzate la linear regression per analizzare il dataframe di esempio con Fabbisogno calorico giornaliero di un uomo in base alla sua età, allenate l'algoritmo, testatelo e poi realizzate un grafico.

# %%
df = pd.read_csv('fabbisogno calorico.csv', index_col=0)
print(df.head())
# Out:
#    eta  calorie
# 0   35     2006
# 1   54     2476
# 2   26     2532
# 3   49     2165
# 4   30     2584

# %%
y.max()
# Out:
# 2900

# %%
print(y.min())
# Out:
# 1800

# %%
X = df[['eta']] #input
y = df['calorie'] #output

# %%
X_train, X_test, y_train ,y_test= train_test_split(X,y)

# %%
model= LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-10.84877872])

# %%
y_pred = model.predict(X_test)

y_pred
# Out:
# array([2235.86263925, 2366.04798386, 2463.68699231, ..., 2507.08210718,
#        2376.89676257, 2344.35042642])

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f"Mean Squared Error: {mse:.2f}")
print(f"R² Score: {r2:.2f}")
print(f"Intercetta: {model.intercept_:.2f}")
print(f"Coefficiente (pendenza): {model.coef_[0]:.2f}")
# Out:
# Mean Squared Error (MSE): 30118.48
# R² Score: 0.50
# Intercetta: 2778.30
# Coefficiente (pendenza): -10.85

# %% [markdown]
# ### Grafico retta e dati

# %%
plt.figure(figsize=(8, 5))
plt.scatter(X, y, color="#10ec6b", label='Dati reali')
plt.plot(X, model.predict(X), color='black', label='Retta di regressione')
plt.title('Età vs Fabbisogno calorico giornaliero')
plt.xlabel('Età (anni)')
plt.ylabel('Fabbisogno calorico (kcal)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Confronto test e predizione

# %%
plt.figure(figsize=(8, 5))
plt.scatter(X_test, y_test, color='skyblue', label='Valori test')
plt.scatter(X_test, y_pred, color='blue', label='Valori predetti')
plt.title('Valori reali vs Predetti (Test set)')
plt.xlabel('Età')
plt.ylabel('Fabbisogno calorico')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import PredictionErrorDisplay

display= PredictionErrorDisplay(y_true=y_test,y_pred=y_pred)
display.plot()
plt.show()
